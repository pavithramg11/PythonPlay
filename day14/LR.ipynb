# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# %%
arr1 = np.random.uniform(0, 1000, 50)
print(arr1)
# Out:
# [114.19880086 803.39787588 813.25381831 108.43721059 214.96740237
#  240.26650821 147.64819612 721.71362374 575.56023993 845.34851969
#  448.87603172 467.73195865 201.40406904 668.50291751 207.98620636
#  474.58855052 418.32979356 439.15054664 761.30085843 307.48585368
#  383.78180798  72.39953811 993.66973939 730.67930596 912.01230875
#   70.06615632 610.49961119 411.13757296  55.95302176 736.78987067
#  867.57537782 825.98286609 185.35386205 356.89392743  80.90797793
#  566.74616643 940.81240123 794.96970105 696.28989282 365.27659538
#  410.85311841 765.10632261 693.52802429 302.06779766 634.68647419
#  302.06932418 508.99553098 141.37670505 470.04160345 609.90699762]

# %%
arr2 = 3*arr1 +2  + np.random.randn(50)*0.1
print(arr2)
# Out:
# [ 344.53529654 2412.35330984 2441.78572012  327.27408059  646.86893051
#   722.74969778  444.95173385 2167.12471001 1728.71057531 2537.95661895
#  1348.55206063 1405.1143793   606.14974982 2007.35386623  625.98181463
#  1425.58266736 1256.85805013 1319.49601408 2285.8632301   924.47134747
#  1153.38772342  219.13697194 2982.99826235 2193.97433801 2738.0278579
#   212.2569106  1833.52521058 1235.23520753  169.8792771  2212.54184637
#  2604.6684979  2479.92919032  557.96614212 1072.67881788  244.6648991
#  1702.20148774 2824.50003299 2386.84346204 2090.78948623 1097.80399909
#  1234.53549707 2297.33990576 2082.54210929  908.19643182 1906.00942286
#   908.18673799 1529.09444111  426.07183982 1412.15157523 1831.6667645 ]

# %%
X = arr1.reshape(-1,1)
y = arr2

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
print("R^2: ", model.score(X_test, y_test))
# Out:
# MSE:  0.003821376167276586
# RMSE:  0.0618172804907866
# R^2:  0.9999999925859612

# %%
print("m: ", model.coef_)
print("c: ", model.intercept_)
# Out:
# m:  [3.00006229]
# c:  1.943348179557006

# %%
#plt.scatter(X_test, y_test, label="Actual data", color="blue" , marker="o")
#plt.scatter(X_test, y_pred, label="Predicted data", color="red", marker="x")
plt.scatter(X_test, y_test, label="Actual data", color="blue")
plt.plot(X_test, y_pred, label="Predicted data", color="red")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression")
plt.show()
