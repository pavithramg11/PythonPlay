# %%
import pandas as pd

df = pd.read_csv("data.csv")

# %%
df.groupby('Store')['Sales'].sum()
# Out:
# Store
# North    350
# South    270
# Name: Sales, dtype: int64

# %%
df.groupby(['Store', 'Product'])['Sales'].mean()
# Out:
# Store  Product
# North  Apple       75.0
#        Orange     200.0
# South  Apple      120.0
#        Orange     150.0
# Name: Sales, dtype: float64

# %%
df['Sales'].sum()
# Out:
# np.int64(620)

# %%
df.groupby('Store')['Sales'].sum()
# Out:
# Store
# North    350
# South    270
# Name: Sales, dtype: int64

# %%
df.groupby('Store')["Sales"]

# %%
df["Store"].unique()
# Out:
# <StringArray>
# ['North', 'South']
# Length: 2, dtype: str

# %%
df["Store"].nunique()
# Out:
# 2
